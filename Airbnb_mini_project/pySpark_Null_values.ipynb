# %% [markdown]
# Useful link : https://www.analyticsvidhya.com/blog/2022/05/data-preprocessing-using-pyspark-handling-missing-values/

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("local_spark").getOrCreate()

# %%
df = spark.read.csv('calendar.csv', header=True)
df.show()
# Out:
# +----------+----------+---------+------+
# |listing_id|      date|available| price|
# +----------+----------+---------+------+
# |    241032|2016-01-04|        t|$85.00|
# |    241032|2016-01-05|        t|$85.00|
# |    241032|2016-01-06|        f|  null|
# |    241032|2016-01-07|        f|  null|
# |    241032|2016-01-08|        f|  null|
# |    241032|2016-01-09|        f|  null|
# |    241032|2016-01-10|        f|  null|
# |    241032|2016-01-11|        f|  null|
# |    241032|2016-01-12|        f|  null|
# |    241032|2016-01-13|        t|$85.00|
# |    241032|2016-01-14|        t|$85.00|
# |    241032|2016-01-15|        f|  null|
# |    241032|2016-01-16|        f|  null|
# |    241032|2016-01-17|        f|  null|
# |    241032|2016-01-18|        t|$85.00|
# |    241032|2016-01-19|        t|$85.00|
# |    241032|2016-01-20|        t|$85.00|
# |    241032|2016-01-21|        f|  null|
# |    241032|2016-01-22|        f|  null|
# |    241032|2016-01-23|        f|  null|
# +----------+----------+---------+------+
# only showing top 20 rows

# %%
#df = spark.read.format("csv").option("header", "true").load("C:/Users/awedo/SpartaGlobal_Projects/Missing Values/calendar.csv")

# %% [markdown]
# IMPORTANT:
# - printSchema() which works in the same way as the “describe” function of pandas.

# %%
# nullable = True means that there are some null values in that column
df.printSchema()
# Out:
# root
#  |-- listing_id: string (nullable = true)
#  |-- date: string (nullable = true)
#  |-- available: string (nullable = true)
#  |-- price: string (nullable = true)

# %% [markdown]
# Counting Null values for single columns

# %%
df.filter(" available is null").count()
# Out:
# 1

# %%
df.filter(" price is null").count()
# Out:
# 415489

# %%
df.filter(" date is null").count()
# Out:
# 1

# %%
# Couting all the values in the columns 
from pyspark.sql.functions import count, col 
df.select([count(col(i)) for i in df.columns]).show()
# Out:
# +-----------------+-----------+----------------+------------+
# |count(listing_id)|count(date)|count(available)|count(price)|
# +-----------------+-----------+----------------+------------+
# |          1246500|    1246499|         1246499|      831011|
# +-----------------+-----------+----------------+------------+

# %%
# Counts all the null values with alias
from pyspark.sql.functions import count, col, when
df.select([count(when(col(i).isNull(),i)).alias(i) for i in df.columns]).show()
# Out:
# +----------+----+---------+------+
# |listing_id|date|available| price|
# +----------+----+---------+------+
# |         0|   1|        1|415489|
# +----------+----+---------+------+

# %% [markdown]
# Dropping the null values in price

# %%
df = df.dropna(subset=['price'],how='any')
df.show()
# Out:
# +----------+----------+---------+------+
# |listing_id|      date|available| price|
# +----------+----------+---------+------+
# |    241032|2016-01-04|        t|$85.00|
# |    241032|2016-01-05|        t|$85.00|
# |    241032|2016-01-13|        t|$85.00|
# |    241032|2016-01-14|        t|$85.00|
# |    241032|2016-01-18|        t|$85.00|
# |    241032|2016-01-19|        t|$85.00|
# |    241032|2016-01-20|        t|$85.00|
# |    241032|2016-01-24|        t|$85.00|
# |    241032|2016-01-25|        t|$85.00|
# |    241032|2016-01-26|        t|$85.00|
# |    241032|2016-01-27|        t|$85.00|
# |    241032|2016-01-28|        t|$85.00|
# |    241032|2016-02-01|        t|$85.00|
# |    241032|2016-02-02|        t|$85.00|
# |    241032|2016-02-03|        t|$85.00|
# |    241032|2016-02-04|        t|$85.00|
# |    241032|2016-02-05|        t|$85.00|
# |    241032|2016-02-06|        t|$85.00|
# |    241032|2016-02-07|        t|$85.00|
# |    241032|2016-02-08|        t|$85.00|
# +----------+----------+---------+------+
# only showing top 20 rows

# %%
# drop = df.na.drop(how='any', subset=['price'])
# drop.show()

# %%
# Checking whether the null value for price has been dropped
df.filter(" price is null").count()
# Out:
# 0

# %%
df.filter("date is null").count()
# Out:
# 0

# %%
df.filter(col('price').isNull()).show()
# Out:
# +----------+----+---------+-----+
# |listing_id|date|available|price|
# +----------+----+---------+-----+
# +----------+----+---------+-----+

# %% [markdown]
# #### Importing the listing dataFrame

# %%
df = spark.read.csv('listings.csv', header=True)
df.show(vertical=True)
# Out:
# -RECORD 0------------------------------------------------
#  id                               | 241032
#  listing_url                      | https://www.airbn...
#  scrape_id                        | 20160104002432
#  last_scraped                     | 2016-01-04
#  name                             | Stylish Queen Ann...
#  summary                          | null
#  space                            | Make your self at...
#  description                      | Make your self at...
#  experiences_offered              | none
#  neighborhood_overview            | null
#  notes                            | null
#  transit                          | null
#  thumbnail_url                    | null
#  medium_url                       | null
#  picture_url                      | https://a1.muscac...
#  xl_picture_url                   | null
#  host_id                          | 956883
#  host_url                         | https://www.airbn...
#  host_name                        | Maija
#  host_since                       | 2011-08-11
#  host_location                    | Seattle, Washingt...
#  host_about                       | I am an artist, i...
#  host_response_time               | within a few hours
#  host_response_rate               | 96%
#  host_acceptance_rate             | 100%
#  host_is_superhost                | f
#  host_thumbnail_url               | https://a0.muscac...
#  host_picture_url                 | https://a0.muscac...
#  host_neighbourhood               | Queen Anne
#  host_listings_count              | 3
#  host_total_listings_count        | 3
#  host_verifications               | ['email', 'phone'...
#  host_has_profile_pic             | t
#  host_identity_verified           | t
#  street                           | Gilman Dr W, Seat...
#  neighbourhood                    | Queen Anne
#  neighbourhood_cleansed           | West Queen Anne
#  neighbourhood_group_cleansed     | Queen Anne
#  city                             | Seattle
#  state                            | WA
#  zipcode                          | 98119
#  market                           | Seattle
#  smart_location                   | Seattle, WA
#  country_code                     | US
#  country                          | United States
#  latitude                         | 47.636289038357184
#  longitude                        | -122.37102519997765
#  is_location_exact                | t
#  property_type                    | Apartment
#  room_type                        | Entire home/apt
#  accommodates                     | 4
#  bathrooms                        | 1.0
#  bedrooms                         | 1
#  beds                             | 1
#  bed_type                         | Real Bed
#  amenities                        | "{TV,""Cable TV""
#  square_feet                      | Internet
#  price                            | ""Wireless Intern...
#  weekly_price                     | ""Air Conditioning""
#  monthly_price                    | Kitchen
#  security_deposit                 | Heating
#  cleaning_fee                     | ""Family/Kid Frie...
#  guests_included                  | Washer
#  extra_people                     | Dryer}"
#  minimum_nights                   | null
#  maximum_nights                   | $85.00
#  calendar_updated                 | null
#  has_availability                 | null
#  availability_30                  | null
#  availability_60                  | null
#  availability_90                  | 2
#  availability_365                 | $5.00
#  calendar_last_scraped            | 1
#  number_of_reviews                | 365
#  first_review                     | 4 weeks ago
#  last_review                      | t
#  review_scores_rating             | 14
#  review_scores_accuracy           | 41
#  review_scores_cleanliness        | 71
#  review_scores_checkin            | 346
#  review_scores_communication      | 2016-01-04
#  review_scores_location           | 207
#  review_scores_value              | 2011-11-01
#  requires_license                 | 2016-01-02
#  license                          | 95
#  jurisdiction_names               | 10
#  instant_bookable                 | 10
#  cancellation_policy              | 10
#  require_guest_profile_picture    | 10
#  require_guest_phone_verification | 9
#  calculated_host_listings_count   | 10
#  reviews_per_month                | f
# -RECORD 1------------------------------------------------
#  id                               | 953595
#  listing_url                      | https://www.airbn...
#  scrape_id                        | 20160104002432
#  last_scraped                     | 2016-01-04
#  name                             | Bright & Airy Que...
#  summary                          | Chemically sensit...
#  space                            | Beautiful, hypoal...
#  description                      | Chemically sensit...
#  experiences_offered              | none
#  neighborhood_overview            | Queen Anne is a w...
#  notes                            | What's up with th...
#  transit                          | Convenient bus st...
#  thumbnail_url                    | https://a0.muscac...
#  medium_url                       | https://a0.muscac...
#  picture_url                      | https://a0.muscac...
#  xl_picture_url                   | https://a0.muscac...
#  host_id                          | 5177328
#  host_url                         | https://www.airbn...
#  host_name                        | Andrea
#  host_since                       | 2013-02-21
#  host_location                    | Seattle, Washingt...
#  host_about                       | Living east coast...
#  host_response_time               | within an hour
#  host_response_rate               | 98%
#  host_acceptance_rate             | 100%
#  host_is_superhost                | t
#  host_thumbnail_url               | https://a0.muscac...
#  host_picture_url                 | https://a0.muscac...
#  host_neighbourhood               | Queen Anne
#  host_listings_count              | 6
#  host_total_listings_count        | 6
#  host_verifications               | ['email', 'phone'...
#  host_has_profile_pic             | t
#  host_identity_verified           | t
#  street                           | 7th Avenue West, ...
#  neighbourhood                    | Queen Anne
#  neighbourhood_cleansed           | West Queen Anne
#  neighbourhood_group_cleansed     | Queen Anne
#  city                             | Seattle
#  state                            | WA
#  zipcode                          | 98119
#  market                           | Seattle
#  smart_location                   | Seattle, WA
#  country_code                     | US
#  country                          | United States
#  latitude                         | 47.63912312136253
#  longitude                        | -122.36566646439582
#  is_location_exact                | t
#  property_type                    | Apartment
#  room_type                        | Entire home/apt
#  accommodates                     | 4
#  bathrooms                        | 1.0
#  bedrooms                         | 1
#  beds                             | 1
#  bed_type                         | Real Bed
#  amenities                        | "{TV,Internet,""W...
#  square_feet                      | Kitchen
#  price                            | ""Free Parking on...
#  weekly_price                     | ""Buzzer/Wireless...
#  monthly_price                    | Heating
#  security_deposit                 | ""Family/Kid Frie...
#  cleaning_fee                     | Washer
#  guests_included                  | Dryer
#  extra_people                     | ""Smoke Detector""
#  minimum_nights                   | ""Carbon Monoxide...
#  maximum_nights                   | ""First Aid Kit""
#  calendar_updated                 | ""Safety Card""
#  has_availability                 | ""Fire Extinguish...
#  availability_30                  | Essentials}"
#  availability_60                  | null
#  availability_90                  | $150.00
#  availability_365                 | $1,000.00
#  calendar_last_scraped            | $3,000.00
#  number_of_reviews                | $100.00
#  first_review                     | $40.00
#  last_review                      | 1
#  review_scores_rating             | $0.00
#  review_scores_accuracy           | 2
#  review_scores_cleanliness        | 90
#  review_scores_checkin            | today
#  review_scores_communication      | t
#  review_scores_location           | 13
#  review_scores_value              | 13
#  requires_license                 | 16
#  license                          | 291
#  jurisdiction_names               | 2016-01-04
#  instant_bookable                 | 43
#  cancellation_policy              | 2013-08-19
#  require_guest_profile_picture    | 2015-12-29
#  require_guest_phone_verification | 96
#  calculated_host_listings_count   | 10
#  reviews_per_month                | 10
# -RECORD 2------------------------------------------------
#  id                               | 3308979
#  listing_url                      | https://www.airbn...
#  scrape_id                        | 20160104002432
#  last_scraped                     | 2016-01-04
#  name                             | New Modern House-...
#  summary                          | New modern house ...
#  space                            | Our house is mode...
#  description                      | New modern house ...
#  experiences_offered              | none
#  neighborhood_overview            | "Upper Queen Anne...
#  notes                            |  restaurants
#  transit                          |  coffee shops and...
#  thumbnail_url                    |  and situated on ...
#  medium_url                       |  the Space Needle...
#  picture_url                      |  Elliott Bay to t...
#  xl_picture_url                   |  the Olympic Moun...
#  host_id                          |  you'll love the ...
#  host_url                         | Our house is loca...
#  host_name                        | A bus stop is jus...
#  host_since                       | null
#  host_location                    | null
#  host_about                       | https://a2.muscac...
#  host_response_time               | null
#  host_response_rate               | 16708587
#  host_acceptance_rate             | https://www.airbn...
#  host_is_superhost                | Jill
#  host_thumbnail_url               | 2014-06-12
#  host_picture_url                 | Seattle, Washingt...
#  host_neighbourhood               | i love living in ...
#  host_listings_count              | within a few hours
#  host_total_listings_count        | 67%
#  host_verifications               | 100%
#  host_has_profile_pic             | f
#  host_identity_verified           | https://a1.muscac...
#  street                           | https://a1.muscac...
#  neighbourhood                    | Queen Anne
#  neighbourhood_cleansed           | 2
#  neighbourhood_group_cleansed     | 2
#  city                             | ['email', 'phone'...
#  state                            | t
#  zipcode                          | t
#  market                           | West Lee Street, ...
#  smart_location                   | Queen Anne
#  country_code                     | West Queen Anne
#  country                          | Queen Anne
#  latitude                         | Seattle
#  longitude                        | WA
#  is_location_exact                | 98119
#  property_type                    | Seattle
#  room_type                        | Seattle, WA
#  accommodates                     | US
#  bathrooms                        | United States
#  bedrooms                         | 47.629724131577355
#  beds                             | -122.3694831756176
#  bed_type                         | t
#  amenities                        | House
#  square_feet                      | Entire home/apt
#  price                            | 11
#  weekly_price                     | 4.5
#  monthly_price                    | 5
#  security_deposit                 | 7
#  cleaning_fee                     | Real Bed
#  guests_included                  | "{TV,""Cable TV""
#  extra_people                     | Internet
#  minimum_nights                   | ""Wireless Intern...
#  maximum_nights                   | ""Air Conditioning""
#  calendar_updated                 | Kitchen
#  has_availability                 | ""Free Parking on...
#  availability_30                  | ""Pets Allowed""
#  availability_60                  | ""Pets live on th...
#  availability_90                  | Dog(s)
#  availability_365                 | Cat(s)
#  calendar_last_scraped            | ""Hot Tub""
#  number_of_reviews                | ""Indoor Fireplace""
#  first_review                     | Heating
#  last_review                      | ""Family/Kid Frie...
#  review_scores_rating             | Washer
#  review_scores_accuracy           | Dryer
#  review_scores_cleanliness        | ""Smoke Detector""
#  review_scores_checkin            | ""Carbon Monoxide...
#  review_scores_communication      | Essentials
#  review_scores_location           | Shampoo}"
#  review_scores_value              | null
#  requires_license                 | $975.00
#  license                          | null
#  jurisdiction_names               | null
#  instant_bookable                 | $1,000.00
#  cancellation_policy              | $300.00
#  require_guest_profile_picture    | 10
#  require_guest_phone_verification | $25.00
#  calculated_host_listings_count   | 4
#  reviews_per_month                | 30
# -RECORD 3------------------------------------------------
#  id                               | 7421966
#  listing_url                      | https://www.airbn...
#  scrape_id                        | 20160104002432
#  last_scraped                     | 2016-01-04
#  name                             | Queen Anne Chateau
#  summary                          | A charming apartm...
#  space                            | null
#  description                      | A charming apartm...
#  experiences_offered              | none
#  neighborhood_overview            | null
#  notes                            | null
#  transit                          | null
#  thumbnail_url                    | null
#  medium_url                       | null
#  picture_url                      | https://a0.muscac...
#  xl_picture_url                   | null
#  host_id                          | 9851441
#  host_url                         | https://www.airbn...
#  host_name                        | Emily
#  host_since                       | 2013-11-06
#  host_location                    | Seattle, Washingt...
#  host_about                       | null
#  host_response_time               | N/A
#  host_response_rate               | N/A
#  host_acceptance_rate             | N/A
#  host_is_superhost                | f
#  host_thumbnail_url               | https://a2.muscac...
#  host_picture_url                 | https://a2.muscac...
#  host_neighbourhood               | Queen Anne
#  host_listings_count              | 1
#  host_total_listings_count        | 1
#  host_verifications               | ['email', 'phone'...
#  host_has_profile_pic             | t
#  host_identity_verified           | t
#  street                           | 8th Avenue West, ...
#  neighbourhood                    | Queen Anne
#  neighbourhood_cleansed           | West Queen Anne
#  neighbourhood_group_cleansed     | Queen Anne
#  city                             | Seattle
#  state                            | WA
#  zipcode                          | 98119
#  market                           | Seattle
#  smart_location                   | Seattle, WA
#  country_code                     | US
#  country                          | United States
#  latitude                         | 47.638473201766416
#  longitude                        | -122.36927912263018
#  is_location_exact                | t
#  property_type                    | Apartment
#  room_type                        | Entire home/apt
#  accommodates                     | 3
#  bathrooms                        | 1.0
#  bedrooms                         | 0
#  beds                             | 2
#  bed_type                         | Real Bed
#  amenities                        | "{Internet,""Wire...
#  square_feet                      | Kitchen
#  price                            | ""Indoor Fireplace""
#  weekly_price                     | Heating
#  monthly_price                    | ""Family/Kid Frie...
#  security_deposit                 | Washer
#  cleaning_fee                     | Dryer
#  guests_included                  | ""Smoke Detector""
#  extra_people                     | ""Carbon Monoxide...
#  minimum_nights                   | ""Safety Card""
#  maximum_nights                   | ""Fire Extinguish...
#  calendar_updated                 | Essentials
#  has_availability                 | Shampoo}"
#  availability_30                  | null
#  availability_60                  | $100.00
#  availability_90                  | $650.00
#  availability_365                 | $2,300.00
#  calendar_last_scraped            | null
#  number_of_reviews                | null
#  first_review                     | 1
#  last_review                      | $0.00
#  review_scores_rating             | 1
#  review_scores_accuracy           | 1125
#  review_scores_cleanliness        | 6 months ago
#  review_scores_checkin            | t
#  review_scores_communication      | 0
#  review_scores_location           | 0
#  review_scores_value              | 0
#  requires_license                 | 143
#  license                          | 2016-01-04
#  jurisdiction_names               | 0
#  instant_bookable                 | null
#  cancellation_policy              | null
#  require_guest_profile_picture    | null
#  require_guest_phone_verification | null
#  calculated_host_listings_count   | null
#  reviews_per_month                | null
# -RECORD 4------------------------------------------------
#  id                               | 278830
#  listing_url                      | https://www.airbn...
#  scrape_id                        | 20160104002432
#  last_scraped                     | 2016-01-04
#  name                             | Charming craftsma...
#  summary                          | Cozy family craft...
#  space                            | Cozy family craft...
#  description                      | Cozy family craft...
#  experiences_offered              | none
#  neighborhood_overview            | We are in the bea...
#  notes                            | Belltown
#  transit                          | The nearest publi...
#  thumbnail_url                    | null
#  medium_url                       | null
#  picture_url                      | https://a1.muscac...
#  xl_picture_url                   | null
#  host_id                          | 1452570
#  host_url                         | https://www.airbn...
#  host_name                        | Emily
#  host_since                       | 2011-11-29
#  host_location                    | Seattle, Washingt...
#  host_about                       | Hi, I live in Sea...
#  host_response_time               | within an hour
#  host_response_rate               | 100%
#  host_acceptance_rate             | N/A
#  host_is_superhost                | f
#  host_thumbnail_url               | https://a0.muscac...
#  host_picture_url                 | https://a0.muscac...
#  host_neighbourhood               | Queen Anne
#  host_listings_count              | 2
#  host_total_listings_count        | 2
#  host_verifications               | ['email', 'phone'...
#  host_has_profile_pic             | t
#  host_identity_verified           | t
#  street                           | 14th Ave W, Seatt...
#  neighbourhood                    | Queen Anne
#  neighbourhood_cleansed           | West Queen Anne
#  neighbourhood_group_cleansed     | Queen Anne
#  city                             | Seattle
#  state                            | WA
#  zipcode                          | 98119
#  market                           | Seattle
#  smart_location                   | Seattle, WA
#  country_code                     | US
#  country                          | United States
#  latitude                         | 47.63291840276724
#  longitude                        | -122.37247063402224
#  is_location_exact                | t
#  property_type                    | House
#  room_type                        | Entire home/apt
#  accommodates                     | 6
#  bathrooms                        | 2.0
#  bedrooms                         | 3
#  beds                             | 3
#  bed_type                         | Real Bed
#  amenities                        | "{TV,""Cable TV""
#  square_feet                      | Internet
#  price                            | ""Wireless Intern...
#  weekly_price                     | Kitchen
#  monthly_price                    | Heating
#  security_deposit                 | ""Family/Kid Frie...
#  cleaning_fee                     | ""Smoke Detector""
#  guests_included                  | ""Carbon Monoxide...
#  extra_people                     | ""First Aid Kit""
#  minimum_nights                   | ""Fire Extinguish...
#  maximum_nights                   | Essentials
#  calendar_updated                 | Shampoo}"
#  has_availability                 | null
#  availability_30                  | $450.00
#  availability_60                  | null
#  availability_90                  | null
#  availability_365                 | $700.00
#  calendar_last_scraped            | $125.00
#  number_of_reviews                | 6
#  first_review                     | $15.00
#  last_review                      | 1
#  review_scores_rating             | 1125
#  review_scores_accuracy           | 7 weeks ago
#  review_scores_cleanliness        | t
#  review_scores_checkin            | 30
#  review_scores_communication      | 60
#  review_scores_location           | 90
#  review_scores_value              | 365
#  requires_license                 | 2016-01-04
#  license                          | 38
#  jurisdiction_names               | 2012-07-10
#  instant_bookable                 | 2015-10-24
#  cancellation_policy              | 92
#  require_guest_profile_picture    | 9
#  require_guest_phone_verification | 9
#  calculated_host_listings_count   | 10
#  reviews_per_month                | 10
# -RECORD 5------------------------------------------------
#  id                               | 5956968
#  listing_url                      | https://www.airbn...
#  scrape_id                        | 20160104002432
#  last_scraped                     | 2016-01-04
#  name                             | Private unit in a...
#  summary                          | We're renting out...
#  space                            | If you include a ...
#  description                      | We're renting out...
#  experiences_offered              | none
#  neighborhood_overview            | This part of Quee...
#  notes                            | Let me know if yo...
#  transit                          | The #1 and #2 bus...
#  thumbnail_url                    | https://a2.muscac...
#  medium_url                       | https://a2.muscac...
#  picture_url                      | https://a2.muscac...
#  xl_picture_url                   | https://a2.muscac...
#  host_id                          | 326758
#  host_url                         | https://www.airbn...
#  host_name                        | Andrew
#  host_since                       | 2010-12-25
#  host_location                    | Seattle, Washingt...
#  host_about                       | I've been fortuna...
#  host_response_time               | N/A
#  host_response_rate               | N/A
#  host_acceptance_rate             | N/A
#  host_is_superhost                | f
#  host_thumbnail_url               | https://a2.muscac...
#  host_picture_url                 | https://a2.muscac...
#  host_neighbourhood               | Queen Anne
#  host_listings_count              | 1
#  host_total_listings_count        | 1
#  host_verifications               | ['email', 'phone'...
#  host_has_profile_pic             | t
#  host_identity_verified           | t
#  street                           | West Comstock Str...
#  neighbourhood                    | Queen Anne
#  neighbourhood_cleansed           | West Queen Anne
#  neighbourhood_group_cleansed     | Queen Anne
#  city                             | Seattle
#  state                            | WA
#  zipcode                          | 98119
#  market                           | Seattle
#  smart_location                   | Seattle, WA
#  country_code                     | US
#  country                          | United States
#  latitude                         | 47.63052548240193
#  longitude                        | -122.36617406518855
#  is_location_exact                | t
#  property_type                    | House
#  room_type                        | Private room
#  accommodates                     | 2
#  bathrooms                        | 1.0
#  bedrooms                         | 1
#  beds                             | 1
#  bed_type                         | Real Bed
#  amenities                        | "{""Wireless Inte...
#  square_feet                      | ""Free Parking on...
#  price                            | Heating
#  weekly_price                     | ""Smoke Detector""
#  monthly_price                    | Essentials
#  security_deposit                 | Shampoo}"
#  cleaning_fee                     | null
#  guests_included                  | $120.00
#  extra_people                     | $800.00
#  minimum_nights                   | null
#  maximum_nights                   | null
#  calendar_updated                 | $40.00
#  has_availability                 | 1
#  availability_30                  | $30.00
#  availability_60                  | 1
#  availability_90                  | 6
#  availability_365                 | 2 weeks ago
#  calendar_last_scraped            | t
#  number_of_reviews                | 0
#  first_review                     | 0
#  last_review                      | 27
#  review_scores_rating             | 302
#  review_scores_accuracy           | 2016-01-04
#  review_scores_cleanliness        | 17
#  review_scores_checkin            | 2015-06-11
#  review_scores_communication      | 2015-09-28
#  review_scores_location           | 95
#  review_scores_value              | 10
#  requires_license                 | 10
#  license                          | 10
#  jurisdiction_names               | 10
#  instant_bookable                 | 10
#  cancellation_policy              | 10
#  require_guest_profile_picture    | f
#  require_guest_phone_verification | null
#  calculated_host_listings_count   | WASHINGTON
#  reviews_per_month                | f
# -RECORD 6------------------------------------------------
#  id                               | 1909058
#  listing_url                      | https://www.airbn...
#  scrape_id                        | 20160104002432
#  last_scraped                     | 2016-01-04
#  name                             | Queen Anne Privat...
#  summary                          | Enjoy a quiet sta...
#  space                            | Enjoy a quiet sta...
#  description                      | Enjoy a quiet sta...
#  experiences_offered              | none
#  neighborhood_overview            | Close restaurants...
#  notes                            | The room now has ...
#  transit                          | The bus goes thro...
#  thumbnail_url                    | https://a2.muscac...
#  medium_url                       | https://a2.muscac...
#  picture_url                      | https://a2.muscac...
#  xl_picture_url                   | https://a2.muscac...
#  host_id                          | 2497928
#  host_url                         | https://www.airbn...
#  host_name                        | Gary And Beth
#  host_since                       | 2012-05-30
#  host_location                    | Seattle, Washingt...
#  host_about                       | We have lived in ...
#  host_response_time               | within an hour
#  host_response_rate               | 100%
#  host_acceptance_rate             | 100%
#  host_is_superhost                | t
#  host_thumbnail_url               | https://a0.muscac...
#  host_picture_url                 | https://a0.muscac...
#  host_neighbourhood               | Queen Anne
#  host_listings_count              | 1
#  host_total_listings_count        | 1
#  host_verifications               | ['email', 'phone'...
#  host_has_profile_pic             | t
#  host_identity_verified           | t
#  street                           | 10th Avenue West,...
#  neighbourhood                    | Queen Anne
#  neighbourhood_cleansed           | West Queen Anne
#  neighbourhood_group_cleansed     | Queen Anne
#  city                             | Seattle
#  state                            | WA
#  zipcode                          | 98119
#  market                           | Seattle
#  smart_location                   | Seattle, WA
#  country_code                     | US
#  country                          | United States
#  latitude                         | 47.63660544532006
#  longitude                        | -122.36851905844937
#  is_location_exact                | t
#  property_type                    | House
#  room_type                        | Private room
#  accommodates                     | 2
#  bathrooms                        | 1.0
#  bedrooms                         | 1
#  beds                             | 1
#  bed_type                         | Real Bed
#  amenities                        | "{""Wireless Inte...
#  square_feet                      | ""Free Parking on...
#  price                            | Heating
#  weekly_price                     | ""Smoke Detector""
#  monthly_price                    | ""First Aid Kit""
#  security_deposit                 | Essentials
#  cleaning_fee                     | Shampoo}"
#  guests_included                  | null
#  extra_people                     | $80.00
#  minimum_nights                   | $575.00
#  maximum_nights                   | null
#  calendar_updated                 | $150.00
#  has_availability                 | null
#  availability_30                  | 1
#  availability_60                  | $10.00
#  availability_90                  | 3
#  availability_365                 | 14
#  calendar_last_scraped            | 5 weeks ago
#  number_of_reviews                | t
#  first_review                     | 20
#  last_review                      | 49
#  review_scores_rating             | 71
#  review_scores_accuracy           | 346
#  review_scores_cleanliness        | 2016-01-04
#  review_scores_checkin            | 58
#  review_scores_communication      | 2014-01-27
#  review_scores_location           | 2015-12-07
#  review_scores_value              | 99
#  requires_license                 | 10
#  license                          | 10
#  jurisdiction_names               | 10
#  instant_bookable                 | 10
#  cancellation_policy              | 10
#  require_guest_profile_picture    | 10
#  require_guest_phone_verification | f
#  calculated_host_listings_count   | null
#  reviews_per_month                | WASHINGTON
# -RECORD 7------------------------------------------------
#  id                               | 856550
#  listing_url                      | https://www.airbn...
#  scrape_id                        | 20160104002432
#  last_scraped                     | 2016-01-04
#  name                             | Tiny Garden cabin...
#  summary                          | Our tiny cabin is...
#  space                            |  This cabin was b...
#  description                      | Our tiny cabin is...
#  experiences_offered              | none
#  neighborhood_overview            | We are centrally ...
#  notes                            | There are three r...
#  transit                          | "the ""D"" line r...
#  thumbnail_url                    | https://a2.muscac...
#  medium_url                       | https://a2.muscac...
#  picture_url                      | https://a2.muscac...
#  xl_picture_url                   | https://a2.muscac...
#  host_id                          | 4016632
#  host_url                         | https://www.airbn...
#  host_name                        | Jean-Marc
#  host_since                       | 2012-10-30
#  host_location                    | Seattle, Washingt...
#  host_about                       | I am a carpenter ...
#  host_response_time               | within an hour
#  host_response_rate               | 100%
#  host_acceptance_rate             | 100%
#  host_is_superhost                | t
#  host_thumbnail_url               | https://a1.muscac...
#  host_picture_url                 | https://a1.muscac...
#  host_neighbourhood               | Queen Anne
#  host_listings_count              | 5
#  host_total_listings_count        | 5
#  host_verifications               | ['email', 'phone'...
#  host_has_profile_pic             | t
#  host_identity_verified           | t
#  street                           | West Wheeler Stre...
#  neighbourhood                    | Queen Anne
#  neighbourhood_cleansed           | West Queen Anne
#  neighbourhood_group_cleansed     | Queen Anne
#  city                             | Seattle
#  state                            | WA
#  zipcode                          | 98119
#  market                           | Seattle
#  smart_location                   | Seattle, WA
#  country_code                     | US
#  country                          | United States
#  latitude                         | 47.64016054121466
#  longitude                        | -122.37585597885769
#  is_location_exact                | t
#  property_type                    | Cabin
#  room_type                        | Private room
#  accommodates                     | 2
#  bathrooms                        | 1.0
#  bedrooms                         | 1
#  beds                             | 1
#  bed_type                         | Real Bed
#  amenities                        | "{""Wireless Inte...
#  square_feet                      | ""Pets live on th...
#  price                            | Dog(s)
#  weekly_price                     | Heating
#  monthly_price                    | ""Family/Kid Frie...
#  security_deposit                 | Essentials
#  cleaning_fee                     | Shampoo}"
#  guests_included                  | null
#  extra_people                     | $60.00
#  minimum_nights                   | $360.00
#  maximum_nights                   | null
#  calendar_updated                 | $150.00
#  has_availability                 | $25.00
#  availability_30                  | 1
#  availability_60                  | $0.00
#  availability_90                  | 2
#  availability_365                 | 7
#  calendar_last_scraped            | yesterday
#  number_of_reviews                | t
#  first_review                     | 22
#  last_review                      | 42
#  review_scores_rating             | 42
#  review_scores_accuracy           | 100
#  review_scores_cleanliness        | 2016-01-04
#  review_scores_checkin            | 173
#  review_scores_communication      | 2013-01-03
#  review_scores_location           | 2016-01-01
#  review_scores_value              | 97
#  requires_license                 | 10
#  license                          | 10
#  jurisdiction_names               | 10
#  instant_bookable                 | 10
#  cancellation_policy              | 9
#  require_guest_profile_picture    | 10
#  require_guest_phone_verification | f
#  calculated_host_listings_count   | null
#  reviews_per_month                | WASHINGTON
# -RECORD 8------------------------------------------------
#  id                               | 4948745
#  listing_url                      | https://www.airbn...
#  scrape_id                        | 20160104002432
#  last_scraped                     | 2016-01-04
#  name                             | Urban Charm || Do...
#  summary                          | Nestled in the he...
#  space                            | Located in the he...
#  description                      | Nestled in the he...
#  experiences_offered              | none
#  neighborhood_overview            | Walking Score: 92...
#  notes                            | null
#  transit                          | "Bus stop to down...
#  thumbnail_url                    |  please inquire f...
#  medium_url                       | https://a0.muscac...
#  picture_url                      | https://a0.muscac...
#  xl_picture_url                   | https://a0.muscac...
#  host_id                          | https://a0.muscac...
#  host_url                         | 2166277
#  host_name                        | https://www.airbn...
#  host_since                       | Aliza
#  host_location                    | 2012-04-18
#  host_about                       | Seattle, Washingt...
#  host_response_time               | I'm a 35 year old...
#  host_response_rate               | N/A
#  host_acceptance_rate             | N/A
#  host_is_superhost                | 100%
#  host_thumbnail_url               | f
#  host_picture_url                 | https://a1.muscac...
#  host_neighbourhood               | https://a1.muscac...
#  host_listings_count              | Queen Anne
#  host_total_listings_count        | 1
#  host_verifications               | 1
#  host_has_profile_pic             | ['email', 'phone'...
#  host_identity_verified           | t
#  street                           | t
#  neighbourhood                    | Queen Anne Avenue...
#  neighbourhood_cleansed           | Queen Anne
#  neighbourhood_group_cleansed     | West Queen Anne
#  city                             | Queen Anne
#  state                            | Seattle
#  zipcode                          | WA
#  market                           | 98109
#  smart_location                   | Seattle
#  country_code                     | Seattle, WA
#  country                          | US
#  latitude                         | United States
#  longitude                        | 47.63241029982899
#  is_location_exact                | -122.35721606914029
#  property_type                    | t
#  room_type                        | Apartment
#  accommodates                     | Private room
#  bathrooms                        | 2
#  bedrooms                         | 1.0
#  beds                             | 1
#  bed_type                         | 1
#  amenities                        | Real Bed
#  square_feet                      | "{TV,""Cable TV""
#  price                            | Internet
#  weekly_price                     | ""Wireless Intern...
#  monthly_price                    | Kitchen
#  security_deposit                 | Breakfast
#  cleaning_fee                     | ""Indoor Fireplace""
#  guests_included                  | Heating
#  extra_people                     | Washer
#  minimum_nights                   | Dryer
#  maximum_nights                   | ""Smoke Detector""
#  calendar_updated                 | ""First Aid Kit""
#  has_availability                 | ""Fire Extinguish...
#  availability_30                  | Essentials
#  availability_60                  | Shampoo}"
#  availability_90                  | null
#  availability_365                 | $90.00
#  calendar_last_scraped            | $500.00
#  number_of_reviews                | $1,700.00
#  first_review                     | null
#  last_review                      | null
#  review_scores_rating             | 1
#  review_scores_accuracy           | $0.00
#  review_scores_cleanliness        | 3
#  review_scores_checkin            | 1125
#  review_scores_communication      | 5 months ago
#  review_scores_location           | t
# ...
#  last_scraped                     | null
#  name                             | null
#  summary                          | null
#  space                            | null
#  description                      | null
#  experiences_offered              | null
#  neighborhood_overview            | null
#  notes                            | null
#  transit                          | null
#  thumbnail_url                    | null
#  medium_url                       | null
#  picture_url                      | null
#  xl_picture_url                   | null
#  host_id                          | null
#  host_url                         | null
#  host_name                        | null
#  host_since                       | null
#  host_location                    | null
#  host_about                       | null
#  host_response_time               | null
#  host_response_rate               | null
#  host_acceptance_rate             | null
#  host_is_superhost                | null
#  host_thumbnail_url               | null
#  host_picture_url                 | null
#  host_neighbourhood               | null
#  host_listings_count              | null
#  host_total_listings_count        | null
#  host_verifications               | null
#  host_has_profile_pic             | null
#  host_identity_verified           | null
#  street                           | null
#  neighbourhood                    | null
#  neighbourhood_cleansed           | null
#  neighbourhood_group_cleansed     | null
#  city                             | null
#  state                            | null
#  zipcode                          | null
#  market                           | null
#  smart_location                   | null
#  country_code                     | null
#  country                          | null
#  latitude                         | null
#  longitude                        | null
#  is_location_exact                | null
#  property_type                    | null
#  room_type                        | null
#  accommodates                     | null
#  bathrooms                        | null
#  bedrooms                         | null
#  beds                             | null
#  bed_type                         | null
#  amenities                        | null
#  square_feet                      | null
#  price                            | null
#  weekly_price                     | null
#  monthly_price                    | null
#  security_deposit                 | null
#  cleaning_fee                     | null
#  guests_included                  | null
#  extra_people                     | null
#  minimum_nights                   | null
#  maximum_nights                   | null
#  calendar_updated                 | null
#  has_availability                 | null
#  availability_30                  | null
#  availability_60                  | null
#  availability_90                  | null
#  availability_365                 | null
#  calendar_last_scraped            | null
#  number_of_reviews                | null
#  first_review                     | null
#  last_review                      | null
#  review_scores_rating             | null
#  review_scores_accuracy           | null
#  review_scores_cleanliness        | null
#  review_scores_checkin            | null
#  review_scores_communication      | null
#  review_scores_location           | null
#  review_scores_value              | null
#  requires_license                 | null
#  license                          | null
#  jurisdiction_names               | null
#  instant_bookable                 | null
#  cancellation_policy              | null
#  require_guest_profile_picture    | null
#  require_guest_phone_verification | null
#  calculated_host_listings_count   | null
#  reviews_per_month                | null
# -RECORD 18-----------------------------------------------
#  id                               | Ellie
#  listing_url                      | null
#  scrape_id                        | null
#  last_scraped                     | null
#  name                             | null
#  summary                          | null
#  space                            | null
#  description                      | null
#  experiences_offered              | null
#  neighborhood_overview            | null
#  notes                            | null
#  transit                          | null
#  thumbnail_url                    | null
#  medium_url                       | null
#  picture_url                      | null
#  xl_picture_url                   | null
#  host_id                          | null
#  host_url                         | null
#  host_name                        | null
#  host_since                       | null
#  host_location                    | null
#  host_about                       | null
#  host_response_time               | null
#  host_response_rate               | null
#  host_acceptance_rate             | null
#  host_is_superhost                | null
#  host_thumbnail_url               | null
#  host_picture_url                 | null
#  host_neighbourhood               | null
#  host_listings_count              | null
#  host_total_listings_count        | null
#  host_verifications               | null
#  host_has_profile_pic             | null
#  host_identity_verified           | null
#  street                           | null
#  neighbourhood                    | null
#  neighbourhood_cleansed           | null
#  neighbourhood_group_cleansed     | null
#  city                             | null
#  state                            | null
#  zipcode                          | null
#  market                           | null
#  smart_location                   | null
#  country_code                     | null
#  country                          | null
#  latitude                         | null
#  longitude                        | null
#  is_location_exact                | null
#  property_type                    | null
#  room_type                        | null
#  accommodates                     | null
#  bathrooms                        | null
#  bedrooms                         | null
#  beds                             | null
#  bed_type                         | null
#  amenities                        | null
#  square_feet                      | null
#  price                            | null
#  weekly_price                     | null
#  monthly_price                    | null
#  security_deposit                 | null
#  cleaning_fee                     | null
#  guests_included                  | null
#  extra_people                     | null
#  minimum_nights                   | null
#  maximum_nights                   | null
#  calendar_updated                 | null
#  has_availability                 | null
#  availability_30                  | null
#  availability_60                  | null
#  availability_90                  | null
#  availability_365                 | null
#  calendar_last_scraped            | null
#  number_of_reviews                | null
#  first_review                     | null
#  last_review                      | null
#  review_scores_rating             | null
#  review_scores_accuracy           | null
#  review_scores_cleanliness        | null
#  review_scores_checkin            | null
#  review_scores_communication      | null
#  review_scores_location           | null
#  review_scores_value              | null
#  requires_license                 | null
#  license                          | null
#  jurisdiction_names               | null
#  instant_bookable                 | null
#  cancellation_policy              | null
#  require_guest_profile_picture    | null
#  require_guest_phone_verification | null
#  calculated_host_listings_count   | null
#  reviews_per_month                | null
# -RECORD 19-----------------------------------------------
#  id                               | ",within an hour,...
#  listing_url                      | *&crop=h:h;*
#  scrape_id                        | *&resize=50:*&out...
#  last_scraped                     | https://a2.muscac...
#  name                             | Queen Anne
#  summary                          | 1
#  space                            | 1
#  description                      | ['email', 'phone'...
#  experiences_offered              | t
#  neighborhood_overview            | t
#  notes                            | West Prospect Str...
#  transit                          | Queen Anne
#  thumbnail_url                    | West Queen Anne
#  medium_url                       | Queen Anne
#  picture_url                      | Seattle
#  xl_picture_url                   | WA
#  host_id                          | 98119
#  host_url                         | Seattle
#  host_name                        | Seattle, WA
#  host_since                       | US
#  host_location                    | United States
#  host_about                       | 47.62950680923431
#  host_response_time               | -122.3676292967417
#  host_response_rate               | t
#  host_acceptance_rate             | House
#  host_is_superhost                | Entire home/apt
#  host_thumbnail_url               | 5
#  host_picture_url                 | 1.0
#  host_neighbourhood               | 2
#  host_listings_count              | 3
#  host_total_listings_count        | Real Bed
#  host_verifications               | "{TV,""Cable TV""
#  host_has_profile_pic             | Internet
#  host_identity_verified           | ""Wireless Intern...
#  street                           | Kitchen
#  neighbourhood                    | Heating
#  neighbourhood_cleansed           | ""Family/Kid Frie...
#  neighbourhood_group_cleansed     | Washer
#  city                             | Dryer
#  state                            | ""Smoke Detector""
#  zipcode                          | ""Carbon Monoxide...
#  market                           | ""First Aid Kit""
#  smart_location                   | ""Safety Card""
#  country_code                     | ""Fire Extinguish...
#  country                          | Essentials
#  latitude                         | Shampoo}"
#  longitude                        | null
#  is_location_exact                | $165.00
#  property_type                    | null
#  room_type                        | $5,000.00
#  accommodates                     | $400.00
#  bathrooms                        | $85.00
#  bedrooms                         | 4
#  beds                             | $20.00
#  bed_type                         | 2
#  amenities                        | 1125
#  square_feet                      | today
#  price                            | t
#  weekly_price                     | 13
#  monthly_price                    | 40
#  security_deposit                 | 63
#  cleaning_fee                     | 337
#  guests_included                  | 2016-01-04
#  extra_people                     | 3
#  minimum_nights                   | 2015-12-16
#  maximum_nights                   | 2016-01-02
#  calendar_updated                 | 100
#  has_availability                 | 10
#  availability_30                  | 10
#  availability_60                  | 9
#  availability_90                  | 9
#  availability_365                 | 10
#  calendar_last_scraped            | 10
#  number_of_reviews                | f
#  first_review                     | null
#  last_review                      | WASHINGTON
#  review_scores_rating             | f
#  review_scores_accuracy           | strict
#  review_scores_cleanliness        | f
#  review_scores_checkin            | f
#  review_scores_communication      | 1
#  review_scores_location           | 3
#  review_scores_value              | null
#  requires_license                 | null
#  license                          | null
#  jurisdiction_names               | null
#  instant_bookable                 | null
#  cancellation_policy              | null
#  require_guest_profile_picture    | null
#  require_guest_phone_verification | null
#  calculated_host_listings_count   | null
#  reviews_per_month                | null
# only showing top 20 rows

# %%
#df = spark.read.format("csv").option("header", "true").load("C:/Users/awedo/SpartaGlobal_Projects/Missing Values/listings.csv")

# %%
# Counts all the null values with alias
from pyspark.sql.functions import count, col, when
df.select([count(when(col(i).isNull(),i)).alias(i) for i in df.columns]).show(vertical=True)
# Out:
# -RECORD 0--------------------------------
#  id                               | 0
#  listing_url                      | 1247
#  scrape_id                        | 1742
#  last_scraped                     | 2038
#  name                             | 2247
#  summary                          | 2629
#  space                            | 3129
#  description                      | 2662
#  experiences_offered              | 2702
#  neighborhood_overview            | 3701
#  notes                            | 4207
#  transit                          | 3670
#  thumbnail_url                    | 3038
#  medium_url                       | 3042
#  picture_url                      | 2810
#  xl_picture_url                   | 3066
#  host_id                          | 2790
#  host_url                         | 2791
#  host_name                        | 2793
#  host_since                       | 2798
#  host_location                    | 2794
#  host_about                       | 3568
#  host_response_time               | 3813
#  host_response_rate               | 3837
#  host_acceptance_rate             | 3858
#  host_is_superhost                | 3880
#  host_thumbnail_url               | 3896
#  host_picture_url                 | 3917
#  host_neighbourhood               | 4138
#  host_listings_count              | 3942
#  host_total_listings_count        | 3952
#  host_verifications               | 3967
#  host_has_profile_pic             | 3982
#  host_identity_verified           | 3986
#  street                           | 3985
#  neighbourhood                    | 4281
#  neighbourhood_cleansed           | 4016
#  neighbourhood_group_cleansed     | 4033
#  city                             | 4036
#  state                            | 4046
#  zipcode                          | 4066
#  market                           | 4077
#  smart_location                   | 4099
#  country_code                     | 4135
#  country                          | 4174
#  latitude                         | 4215
#  longitude                        | 4231
#  is_location_exact                | 4257
#  property_type                    | 4283
#  room_type                        | 4275
#  accommodates                     | 4293
#  bathrooms                        | 4274
#  bedrooms                         | 4250
#  beds                             | 4220
#  bed_type                         | 4217
#  amenities                        | 4193
#  square_feet                      | 4228
#  price                            | 4160
#  weekly_price                     | 4205
#  monthly_price                    | 4214
#  security_deposit                 | 4228
#  cleaning_fee                     | 4218
#  guests_included                  | 4235
#  extra_people                     | 4301
#  minimum_nights                   | 4355
#  maximum_nights                   | 4451
#  calendar_updated                 | 4560
#  has_availability                 | 4643
#  availability_30                  | 4725
#  availability_60                  | 4788
#  availability_90                  | 4791
#  availability_365                 | 4788
#  calendar_last_scraped            | 4734
#  number_of_reviews                | 4714
#  first_review                     | 4649
#  last_review                      | 4595
#  review_scores_rating             | 4533
#  review_scores_accuracy           | 4515
#  review_scores_cleanliness        | 4547
#  review_scores_checkin            | 4552
#  review_scores_communication      | 4608
#  review_scores_location           | 4693
#  review_scores_value              | 4805
#  requires_license                 | 4884
#  license                          | 5051
#  jurisdiction_names               | 5113
#  instant_bookable                 | 5233
#  cancellation_policy              | 5345
#  require_guest_profile_picture    | 5444
#  require_guest_phone_verification | 5499
#  calculated_host_listings_count   | 5566
#  reviews_per_month                | 5650

# %%
df.dtypes
# Out:
# [('id', 'string'),
#  ('listing_url', 'string'),
#  ('scrape_id', 'string'),
#  ('last_scraped', 'string'),
#  ('name', 'string'),
#  ('summary', 'string'),
#  ('space', 'string'),
#  ('description', 'string'),
#  ('experiences_offered', 'string'),
#  ('neighborhood_overview', 'string'),
#  ('notes', 'string'),
#  ('transit', 'string'),
#  ('thumbnail_url', 'string'),
#  ('medium_url', 'string'),
#  ('picture_url', 'string'),
#  ('xl_picture_url', 'string'),
#  ('host_id', 'string'),
#  ('host_url', 'string'),
#  ('host_name', 'string'),
#  ('host_since', 'string'),
#  ('host_location', 'string'),
#  ('host_about', 'string'),
#  ('host_response_time', 'string'),
#  ('host_response_rate', 'string'),
#  ('host_acceptance_rate', 'string'),
#  ('host_is_superhost', 'string'),
#  ('host_thumbnail_url', 'string'),
#  ('host_picture_url', 'string'),
#  ('host_neighbourhood', 'string'),
#  ('host_listings_count', 'string'),
#  ('host_total_listings_count', 'string'),
#  ('host_verifications', 'string'),
#  ('host_has_profile_pic', 'string'),
#  ('host_identity_verified', 'string'),
#  ('street', 'string'),
#  ('neighbourhood', 'string'),
#  ('neighbourhood_cleansed', 'string'),
#  ('neighbourhood_group_cleansed', 'string'),
#  ('city', 'string'),
#  ('state', 'string'),
#  ('zipcode', 'string'),
#  ('market', 'string'),
#  ('smart_location', 'string'),
#  ('country_code', 'string'),
#  ('country', 'string'),
#  ('latitude', 'string'),
#  ('longitude', 'string'),
#  ('is_location_exact', 'string'),
#  ('property_type', 'string'),
#  ('room_type', 'string'),
#  ('accommodates', 'string'),
#  ('bathrooms', 'string'),
#  ('bedrooms', 'string'),
#  ('beds', 'string'),
#  ('bed_type', 'string'),
#  ('amenities', 'string'),
#  ('square_feet', 'string'),
#  ('price', 'string'),
#  ('weekly_price', 'string'),
#  ('monthly_price', 'string'),
#  ('security_deposit', 'string'),
#  ('cleaning_fee', 'string'),
#  ('guests_included', 'string'),
#  ('extra_people', 'string'),
#  ('minimum_nights', 'string'),
#  ('maximum_nights', 'string'),
#  ('calendar_updated', 'string'),
#  ('has_availability', 'string'),
#  ('availability_30', 'string'),
#  ('availability_60', 'string'),
#  ('availability_90', 'string'),
#  ('availability_365', 'string'),
#  ('calendar_last_scraped', 'string'),
#  ('number_of_reviews', 'string'),
#  ('first_review', 'string'),
#  ('last_review', 'string'),
#  ('review_scores_rating', 'string'),
#  ('review_scores_accuracy', 'string'),
#  ('review_scores_cleanliness', 'string'),
#  ('review_scores_checkin', 'string'),
#  ('review_scores_communication', 'string'),
#  ('review_scores_location', 'string'),
#  ('review_scores_value', 'string'),
#  ('requires_license', 'string'),
#  ('license', 'string'),
#  ('jurisdiction_names', 'string'),
#  ('instant_bookable', 'string'),
#  ('cancellation_policy', 'string'),
#  ('require_guest_profile_picture', 'string'),
#  ('require_guest_phone_verification', 'string'),
#  ('calculated_host_listings_count', 'string'),
#  ('reviews_per_month', 'string')]

# %%
# cols = ("firstname","middlename","lastname")

# df.drop(*cols) \
#    .printSchema()

# %%
df.printSchema()
# Out:
# root
#  |-- id: string (nullable = true)
#  |-- listing_url: string (nullable = true)
#  |-- scrape_id: string (nullable = true)
#  |-- last_scraped: string (nullable = true)
#  |-- name: string (nullable = true)
#  |-- summary: string (nullable = true)
#  |-- space: string (nullable = true)
#  |-- description: string (nullable = true)
#  |-- experiences_offered: string (nullable = true)
#  |-- neighborhood_overview: string (nullable = true)
#  |-- notes: string (nullable = true)
#  |-- transit: string (nullable = true)
#  |-- thumbnail_url: string (nullable = true)
#  |-- medium_url: string (nullable = true)
#  |-- picture_url: string (nullable = true)
#  |-- xl_picture_url: string (nullable = true)
#  |-- host_id: string (nullable = true)
#  |-- host_url: string (nullable = true)
#  |-- host_name: string (nullable = true)
#  |-- host_since: string (nullable = true)
#  |-- host_location: string (nullable = true)
#  |-- host_about: string (nullable = true)
#  |-- host_response_time: string (nullable = true)
#  |-- host_response_rate: string (nullable = true)
#  |-- host_acceptance_rate: string (nullable = true)
#  |-- host_is_superhost: string (nullable = true)
#  |-- host_thumbnail_url: string (nullable = true)
#  |-- host_picture_url: string (nullable = true)
#  |-- host_neighbourhood: string (nullable = true)
#  |-- host_listings_count: string (nullable = true)
#  |-- host_total_listings_count: string (nullable = true)
#  |-- host_verifications: string (nullable = true)
#  |-- host_has_profile_pic: string (nullable = true)
#  |-- host_identity_verified: string (nullable = true)
#  |-- street: string (nullable = true)
#  |-- neighbourhood: string (nullable = true)
#  |-- neighbourhood_cleansed: string (nullable = true)
#  |-- neighbourhood_group_cleansed: string (nullable = true)
#  |-- city: string (nullable = true)
#  |-- state: string (nullable = true)
#  |-- zipcode: string (nullable = true)
#  |-- market: string (nullable = true)
#  |-- smart_location: string (nullable = true)
#  |-- country_code: string (nullable = true)
#  |-- country: string (nullable = true)
#  |-- latitude: string (nullable = true)
#  |-- longitude: string (nullable = true)
#  |-- is_location_exact: string (nullable = true)
#  |-- property_type: string (nullable = true)
#  |-- room_type: string (nullable = true)
#  |-- accommodates: string (nullable = true)
#  |-- bathrooms: string (nullable = true)
#  |-- bedrooms: string (nullable = true)
#  |-- beds: string (nullable = true)
#  |-- bed_type: string (nullable = true)
#  |-- amenities: string (nullable = true)
#  |-- square_feet: string (nullable = true)
#  |-- price: string (nullable = true)
#  |-- weekly_price: string (nullable = true)
#  |-- monthly_price: string (nullable = true)
#  |-- security_deposit: string (nullable = true)
#  |-- cleaning_fee: string (nullable = true)
#  |-- guests_included: string (nullable = true)
#  |-- extra_people: string (nullable = true)
#  |-- minimum_nights: string (nullable = true)
#  |-- maximum_nights: string (nullable = true)
#  |-- calendar_updated: string (nullable = true)
#  |-- has_availability: string (nullable = true)
#  |-- availability_30: string (nullable = true)
#  |-- availability_60: string (nullable = true)
#  |-- availability_90: string (nullable = true)
#  |-- availability_365: string (nullable = true)
#  |-- calendar_last_scraped: string (nullable = true)
#  |-- number_of_reviews: string (nullable = true)
#  |-- first_review: string (nullable = true)
#  |-- last_review: string (nullable = true)
#  |-- review_scores_rating: string (nullable = true)
#  |-- review_scores_accuracy: string (nullable = true)
#  |-- review_scores_cleanliness: string (nullable = true)
#  |-- review_scores_checkin: string (nullable = true)
#  |-- review_scores_communication: string (nullable = true)
#  |-- review_scores_location: string (nullable = true)
#  |-- review_scores_value: string (nullable = true)
#  |-- requires_license: string (nullable = true)
#  |-- license: string (nullable = true)
#  |-- jurisdiction_names: string (nullable = true)
#  |-- instant_bookable: string (nullable = true)
#  |-- cancellation_policy: string (nullable = true)
#  |-- require_guest_profile_picture: string (nullable = true)
#  |-- require_guest_phone_verification: string (nullable = true)
#  |-- calculated_host_listings_count: string (nullable = true)
#  |-- reviews_per_month: string (nullable = true)

# %%
# Separated the original data frame into 2 groups and assigned them new variable
numerical_value = df.columns[df.dtypes != 'object']
categorical_value = df.columns[df.dtypes == 'object']

# %%
print(numerical_value)
print(categorical_value)
